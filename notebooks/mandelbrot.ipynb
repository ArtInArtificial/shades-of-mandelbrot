# %%
# Fractal : Mandelbrot Set

# %%
ITERATIONS = 1000

# %%
import numpy as np

get_ipython().run_line_magic('matplotlib', 'inline')
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
# set the location and size of the atlas rectangle
xvalues = np.linspace(-0.22, -0.21, 1000)
yvalues = np.linspace(-0.70, -0.69, 1000)

# %%
# size of these lists of x and y values
xlen = len(xvalues)
ylen = len(yvalues)

# %%
def mandel(c, maxiter):
    # starting value of complex z is 0+0i before iterations update it
    z = complex(0,0)
    # start iterating and stop when it's done maxiter times
    for iteration in range(maxiter):
       
        z = (z*z) + c
       
        if abs(z) > 4:
            break
            
        
    # return the number of iter
    return iteration

# %%
atlas = np.empty((xlen,ylen))

for ix in range(xlen):
    for iy in range(ylen):
        
        cx = xvalues[ix]
        cy = yvalues[iy]
        c = np.complex(cx,cy)
        
        atlas[ix,iy] = mandel(c,ITERATIONS)
        
        pass
    pass

# %%
plt.figure(figsize=(18,18))

# %%
plt.imshow(atlas.T, interpolation="nearest",cmap="jet")

# %%
# TODO : Succesfully saving images
# Status: Done

# %%
# black and white 
plt.imsave("001.png",atlas.T)

# %%
# "jet"
plt.imsave("002.png",atlas.T,cmap="jet")

# %%
cmaps = plt.colormaps()

i = 1
for _ in cmaps:
    filename = "mandelbrot" + "00" + str(i) + ".png"
    plt.imsave(filename,atlas.T,cmap=_)
    i += 1
